# %%
# !pip install meshio
# Out:
# Requirement already satisfied: meshio in /opt/python/3.10.8/lib/python3.10/site-packages (5.3.4)
# Requirement already satisfied: numpy in /home/codespace/.local/lib/python3.10/site-packages (from meshio) (1.25.0)
# Requirement already satisfied: rich in /opt/python/3.10.8/lib/python3.10/site-packages (from meshio) (13.5.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/python/3.10.8/lib/python3.10/site-packages (from rich->meshio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from rich->meshio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/python/3.10.8/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->meshio) (0.1.2)
#
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python -m pip install --upgrade pip

# %%
import torch
import math
from simple_fem import FEM, import_mesh, Quad
import matplotlib.pyplot as plt
from math import sqrt
import meshio as meshio
import numpy as np

torch.set_default_dtype(torch.double)

# %%
# Import mesh with element size factor 0.26 created using gmsh
hood = import_mesh("hoodquad.vtk", 50000.0, 0.33)
# Units = 50000 = 50 GPa, i.e. 1000 = 1 GPa, 1.0 = 1 MPa

# hood.constraints[37:38, 1] = True # Away from the corners
# hood.constraints[46:47, 1] = True # Away from the corners

hood.constraints[50, 1] = True # Away from the corners
hood.constraints[43, 1] = True # Away from the corners


# Front corners
hood.forces[0, 1] = -1000.0 # Right corner
hood.forces[0, 0] = 1000.0 # Right corner
hood.forces[3, :] = -1000.0 # Left corner
hood.forces[4, 1] = -1000.0 # Frontmost corner

# Forces converge upto 2000 MPa, beyond which the structure changes or fails to converge.

# Back corners
hood.constraints[1, :] = True
hood.constraints[2, :] = True

# Material properties
nu = 0.33
E = 50000.0

# Thickness
d = 0.1
thickness = d * torch.ones(len(hood.elements))

# Plot the fillet
Tria = FEM(hood.nodes, hood.elements, hood.forces, hood.constraints, thickness=thickness, E=E, nu=nu)
Tria.plot()

# %%
# Solve
u, f = Tria.solve()

# Plot
Tria.plot(u, node_property=torch.norm(u, dim=1))

# %%
def bisection(f, a, b, max_iter=50, tol=1e-12):
    # Bisection method always finds a root, even with highly non-linear grad
    i = 0
    while (b - a) > tol:
        c = (a + b) / 2.0
        if i > max_iter:
            raise Exception(f"Bisection did not converge in {max_iter} iterations.")
        if f(a) * f(c) > 0:
            a = c
        else:
            b = c
        i += 1
    return c

# %%
def optimize(fem, rho_0, rho_min, rho_max, V_0, iter=1, xi=0.5, m=0.2, p=1.0, r=0.0):
    rho = [rho_0]
    vols = d * fem.areas()

    # Check if there is a feasible solution before starting iteration
    if torch.inner(rho_min, vols) > V_0:
        raise Exception("rho_min is not compatible with V_0.")

    # Precompute filter weights
    if r > 0.0:
        H = r - fem.dist
        H[fem.dist > r] = 0.0

    # Iterate solutions
    for k in range(iter):
        # Adjust thickness variables
        fem.thickness = d * rho[k] ** p

        # Compute solution
        u_k, f_k = fem.solve()

        # Compute sensitivities
        w_k = fem.element_strain_energies(u_k)
        sensitivity = -p * d * rho[k] ** (p - 1) * 2.0 * w_k

        # Filter sensitivities (if r provided)
        if r > 0.0:
            sensitivity = H @ (rho[k] * sensitivity) / H.sum(dim=0) / rho[k]

        # For a certain value of mu, apply the iteration scheme
        def make_step(mu):
            G_k = -sensitivity / (mu * vols)
            upper = torch.min(rho_max, (1 + m) * rho[k])
            lower = torch.max(rho_min, (1 - m) * rho[k])
            rho_trial = G_k**xi * rho[k]
            return torch.maximum(torch.minimum(rho_trial, upper), lower)

        # Constraint function
        def g(mu):
            rho_k = make_step(mu)
            return torch.dot(rho_k, vols) - V_0

        # Find the root of g(mu)
        mu = bisection(g, 1e-10, 100.0)

        # Evaluation
        compliance = torch.inner(f_k.ravel(), u_k.ravel())
        print(f"Iteration k={k} - Compliance: {compliance:.5f}")

        rho.append(make_step(mu))

    return rho

# %%
# Initial thickness, minimum thickness, maximum thickness
rho_0 = 0.5 * torch.ones(len(hood.elements))
rho_min = 0.01 * torch.ones_like(rho_0)
rho_max = 1.0 * torch.ones_like(rho_0)

# Initial volume (40% of maximum design volume)
vols = d * hood.areas()
V0 = 0.4 * vols.sum()

# %%
# Optimize and visualize results
d_opt = optimize(hood, rho_0, rho_min, rho_max, V0, iter=150, p=6, r=14)
# Use p = 6 and r = 14 for convergence in 150 iterations.
hood.plot(element_property=d_opt[-1])
# Out:
# Iteration k=0 - Compliance: 266942.42014
# Iteration k=1 - Compliance: 90273.00618
# Iteration k=2 - Compliance: 77090.25996
# Iteration k=3 - Compliance: 36073.92793
# Iteration k=4 - Compliance: 50310.63918
# Iteration k=5 - Compliance: 29985.88554
# Iteration k=6 - Compliance: 41171.22052
# Iteration k=7 - Compliance: 23541.55980
# Iteration k=8 - Compliance: 43874.32449
# Iteration k=9 - Compliance: 22216.50997
# Iteration k=10 - Compliance: 35076.28499
# Iteration k=11 - Compliance: 22073.63593
# Iteration k=12 - Compliance: 20280.24957
# Iteration k=13 - Compliance: 16525.90077
# Iteration k=14 - Compliance: 14673.11343
# Iteration k=15 - Compliance: 12562.56966
# Iteration k=16 - Compliance: 11303.13837
# Iteration k=17 - Compliance: 10583.33084
# Iteration k=18 - Compliance: 10246.63301
# Iteration k=19 - Compliance: 9958.55116
# Iteration k=20 - Compliance: 9848.66111
# Iteration k=21 - Compliance: 9777.31840
# Iteration k=22 - Compliance: 9745.43281
# Iteration k=23 - Compliance: 9648.65221
# Iteration k=24 - Compliance: 9625.07870
# Iteration k=25 - Compliance: 9517.21528
# Iteration k=26 - Compliance: 9557.87027
# Iteration k=27 - Compliance: 9406.06769
# Iteration k=28 - Compliance: 9461.36475
# Iteration k=29 - Compliance: 9298.10050
# Iteration k=30 - Compliance: 9312.02402
# Iteration k=31 - Compliance: 9160.16223
# Iteration k=32 - Compliance: 9246.65022
# Iteration k=33 - Compliance: 9109.01055
# Iteration k=34 - Compliance: 9203.80618
# Iteration k=35 - Compliance: 9094.61505
# Iteration k=36 - Compliance: 9212.87304
# Iteration k=37 - Compliance: 9087.36507
# Iteration k=38 - Compliance: 9165.54091
# Iteration k=39 - Compliance: 9080.77021
# Iteration k=40 - Compliance: 9189.71891
# Iteration k=41 - Compliance: 9077.57597
# Iteration k=42 - Compliance: 9152.93177
# Iteration k=43 - Compliance: 9067.48972
# Iteration k=44 - Compliance: 9160.43117
# Iteration k=45 - Compliance: 9063.77886
# Iteration k=46 - Compliance: 9140.40631
# Iteration k=47 - Compliance: 9052.76941
# Iteration k=48 - Compliance: 9130.69460
# Iteration k=49 - Compliance: 9048.89763
# Iteration k=50 - Compliance: 9121.30599
# Iteration k=51 - Compliance: 9046.83402
# Iteration k=52 - Compliance: 9115.59958
# Iteration k=53 - Compliance: 9049.47778
# Iteration k=54 - Compliance: 9111.59392
# Iteration k=55 - Compliance: 9049.94091
# Iteration k=56 - Compliance: 9107.29616
# Iteration k=57 - Compliance: 9051.39469
# Iteration k=58 - Compliance: 9103.82416
# Iteration k=59 - Compliance: 9052.46661
# Iteration k=60 - Compliance: 9100.53384
# Iteration k=61 - Compliance: 9052.75797
# Iteration k=62 - Compliance: 9098.70861
# Iteration k=63 - Compliance: 9050.34830
# Iteration k=64 - Compliance: 9096.74920
# Iteration k=65 - Compliance: 9049.34920
# Iteration k=66 - Compliance: 9096.00799
# Iteration k=67 - Compliance: 9048.01500
# Iteration k=68 - Compliance: 9095.45056
# Iteration k=69 - Compliance: 9046.11075
# Iteration k=70 - Compliance: 9094.62713
# Iteration k=71 - Compliance: 9042.94235
# Iteration k=72 - Compliance: 9093.73351
# Iteration k=73 - Compliance: 9038.70777
# Iteration k=74 - Compliance: 9092.67034
# Iteration k=75 - Compliance: 9035.17607
# Iteration k=76 - Compliance: 9092.27964
# Iteration k=77 - Compliance: 9032.70687
# Iteration k=78 - Compliance: 9092.14485
# Iteration k=79 - Compliance: 9030.15835
# Iteration k=80 - Compliance: 9092.00819
# Iteration k=81 - Compliance: 9028.32990
# Iteration k=82 - Compliance: 9092.12979
# Iteration k=83 - Compliance: 9026.88892
# Iteration k=84 - Compliance: 9092.33787
# Iteration k=85 - Compliance: 9025.75281
# Iteration k=86 - Compliance: 9092.67654
# Iteration k=87 - Compliance: 9024.49924
# Iteration k=88 - Compliance: 9093.00742
# Iteration k=89 - Compliance: 9023.60718
# Iteration k=90 - Compliance: 9093.44253
# Iteration k=91 - Compliance: 9022.87483
# Iteration k=92 - Compliance: 9093.84694
# Iteration k=93 - Compliance: 9022.29615
# Iteration k=94 - Compliance: 9094.15114
# Iteration k=95 - Compliance: 9021.85542
# Iteration k=96 - Compliance: 9094.54682
# Iteration k=97 - Compliance: 9021.49195
# Iteration k=98 - Compliance: 9095.01896
# Iteration k=99 - Compliance: 9021.33339
# Iteration k=100 - Compliance: 9095.51593
# Iteration k=101 - Compliance: 9021.26859
# Iteration k=102 - Compliance: 9096.13612
# Iteration k=103 - Compliance: 9021.28184
# Iteration k=104 - Compliance: 9096.46910
# Iteration k=105 - Compliance: 9021.29578
# Iteration k=106 - Compliance: 9096.92405
# Iteration k=107 - Compliance: 9021.35946
# Iteration k=108 - Compliance: 9097.07920
# Iteration k=109 - Compliance: 9021.56421
# Iteration k=110 - Compliance: 9097.72384
# Iteration k=111 - Compliance: 9021.62151
# Iteration k=112 - Compliance: 9097.87480
# Iteration k=113 - Compliance: 9021.50547
# Iteration k=114 - Compliance: 9098.35007
# Iteration k=115 - Compliance: 9021.45127
# Iteration k=116 - Compliance: 9098.41990
# Iteration k=117 - Compliance: 9021.32392
# Iteration k=118 - Compliance: 9098.86953
# Iteration k=119 - Compliance: 9021.27948
# Iteration k=120 - Compliance: 9098.80949
# Iteration k=121 - Compliance: 9021.13463
# Iteration k=122 - Compliance: 9099.26594
# Iteration k=123 - Compliance: 9021.06393
# Iteration k=124 - Compliance: 9099.07298
# Iteration k=125 - Compliance: 9020.89409
# Iteration k=126 - Compliance: 9099.58947
# Iteration k=127 - Compliance: 9020.85510
# Iteration k=128 - Compliance: 9098.94442
# Iteration k=129 - Compliance: 9020.58523
# Iteration k=130 - Compliance: 9099.92861
# Iteration k=131 - Compliance: 9020.62247
# Iteration k=132 - Compliance: 9098.40635
# Iteration k=133 - Compliance: 9020.18163
# Iteration k=134 - Compliance: 9100.50628
# Iteration k=135 - Compliance: 9020.42191
# Iteration k=136 - Compliance: 9097.20713
# Iteration k=137 - Compliance: 9019.70217
# Iteration k=138 - Compliance: 9101.82074
# Iteration k=139 - Compliance: 9020.44429
# Iteration k=140 - Compliance: 9094.88436
# Iteration k=141 - Compliance: 9019.01429
# Iteration k=142 - Compliance: 9104.91485
# Iteration k=143 - Compliance: 9020.54790
# Iteration k=144 - Compliance: 9090.26319
# Iteration k=145 - Compliance: 9017.44431
# Iteration k=146 - Compliance: 9111.35763
# Iteration k=147 - Compliance: 9020.95572
# Iteration k=148 - Compliance: 9081.44286
# Iteration k=149 - Compliance: 9015.60147

# %%
import matplotlib.pyplot as plt

plt.plot(torch.stack(d_opt).detach())
plt.xlabel("Iteration")
plt.ylabel("Values $d_i$")
plt.grid()

# %%
plt.figure()
plt.hist(d_opt[-1], density=True, bins=100, histtype='step')
plt.xlabel("Values $G_j$")
plt.ylabel("Density")
plt.title("Histogram of Optimality factor G at final step")
plt.xlim((0, 1.5))
plt.grid()
